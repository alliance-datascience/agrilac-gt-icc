# %% [markdown]
# # Lectura de los datos historicos actualizados del 2007 a la fecha

# %%
import yaml
import pandas as pd
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import glob
from pathlib import PureWindowsPath
from datetime import datetime
import re
import warnings
import os
import pyarrow  
import fastparquet  

warnings.filterwarnings("ignore")
# set the max columns to none
pd.set_option('display.max_columns', None)

# %%
with open("D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/Carpeta_compartir/data.yaml") as f:
    parametros=yaml.load(f,Loader=yaml.FullLoader)

# %%
dataframes=[]
data_clear=[]
for csv in filenames:
    name_df = re.split(r'[^a-zA-Z0-9\s]', csv)[-2]
    name_df = re.sub(r"\s+", '_', name_df).lower()
    dataframes.append(name_df)
    print(name_df)
    vars()[name_df] = pd.read_excel(csv, index_col=None)
    if vars()[name_df].shape[1]==9:
        vars()[name_df].columns = ["estacion", "fecha", "temperatura", 
        "radiacion", "humedad_relativa", "precipitacion",
         "velocidad_viento", "mojadura", "direccion_viento"]
        vars()[name_df]["presion_atm"]=np.nan
    else:
        vars()[name_df].columns = ["estacion", "fecha", "temperatura", 
        "radiacion", "humedad_relativa", "precipitacion",
         "velocidad_viento", "mojadura", "direccion_viento",
         "presion_atm"]
    #quitando caracteres especiales
    # para qitar caracteres especiales y/o espacios
    vars()[name_df] = vars()[name_df].replace(r'\W+', '', regex=True)
    vars()[name_df] = vars()[name_df].replace(r'\s+', ' ', regex=True)
    vars()[name_df] = vars()[name_df].replace("", np.nan, regex=True)
    vars()[name_df] = vars()[name_df].replace(" ", np.nan, regex=True)
    #formato
    vars()[name_df][[
        'temperatura',
        'radiacion',
        'precipitacion',
        'mojadura'
    ]] = vars()[name_df][[
        'temperatura',
        'radiacion',
        'precipitacion',
        'mojadura'
    ]].apply(pd.to_numeric)
    print('guardando')
    df1=pd.DataFrame(vars()[name_df])
    data_clear.append((df1))
    print(dataframes)
# Out:
# agua_santa
# guardando
# ['agua_santa']
# alamo
# guardando
# ['agua_santa', 'alamo']
# amazonas
# guardando
# ['agua_santa', 'alamo', 'amazonas']
# balsamo
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo']
# bonanza
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza']
# bougambilia
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia']
# cengicana
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana']
# central_izalco
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco']
# chaparrastique
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique']
# chiquirines
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines']
# cocales
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales']
# concepcion
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion']
# copal
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal']
# costa_brava
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava']
# el_carmen
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen']
# el_platanar
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar']
# irlanda
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda']
# la_candelaria
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria']
# la_giralda
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda']
# la_joya
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya']
# la_maquina
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina']
# lorena
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena']
# monte_alegre
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre']
# naranjales
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales']
# peten_oficina
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina']
# providencia
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia']
# pueblo_real
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real']
# puyumate
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate']
# san_antonio_del_valle
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle']
# san_clemente
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente']
# san_nicolas
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas']
# san_rafael
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael']
# santa_teresa
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa']
# sotzil
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'sotzil']
# tehuantepec
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'sotzil', 'tehuantepec']
# trinidad_magdalena
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'sotzil', 'tehuantepec', 'trinidad_magdalena']
# trinidad
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'sotzil', 'tehuantepec', 'trinidad_magdalena', 'trinidad']
# tulula
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'sotzil', 'tehuantepec', 'trinidad_magdalena', 'trinidad', 'tulula']
# xoluta
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'sotzil', 'tehuantepec', 'trinidad_magdalena', 'trinidad', 'tulula', 'xoluta']
# yepocapa
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_joya', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'sotzil', 'tehuantepec', 'trinidad_magdalena', 'trinidad', 'tulula', 'xoluta', 'yepocapa']

# %%
dfs = pd.concat(data_clear, axis=0, ignore_index=True)
# Out:
#    estacion               fecha  temperatura  radiacion  humedad_relativa  \
# 0  CASSAAGS 2020-06-11 00:15:00          NaN        NaN               NaN
# 1  CASSAAGS 2020-06-11 00:30:00          NaN        NaN               NaN
# 2  CASSAAGS 2020-06-11 00:45:00          NaN        NaN               NaN
# 3  CASSAAGS 2020-06-11 01:00:00          NaN        NaN               NaN
# 4  CASSAAGS 2020-06-11 01:15:00          NaN        NaN               NaN
#
#    precipitacion  velocidad_viento  mojadura  direccion_viento  presion_atm
# 0            NaN               NaN       NaN               NaN          NaN
# 1            NaN               NaN       NaN               NaN          NaN
# 2            NaN               NaN       NaN               NaN          NaN
# 3            NaN               NaN       NaN               NaN          NaN
# 4            NaN               NaN       NaN               NaN          NaN

# %%
dfs.to_parquet('icc_station_actual.parquet')
