# %% [markdown]
# ## Actualización de históricos
#
# ##### Este notebook tiene como objetivo leer cada una de las hojas del excel de control de calidad de las estaciones meteorologicas de las que esta a cargo ICC y actulizar la información en los archivos historicos de cada estación

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import glob
from pathlib import PureWindowsPath
from datetime import datetime
import re
import warnings
import os

warnings.filterwarnings("ignore")
# set the max columns to none
pd.set_option('display.max_columns', None)

# %% [markdown]
# Lectura de los archivos historicos

# %%
# get data file names
path =r'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Datos exploratorios/ESTACIONES SIM'
filenames = glob.glob(path + "/*.xlsx")

# %% [markdown]
# ### Limpieza de las bases historicas - se nombran columnas
#
# ##### Se guardan las bases de cada estación en una lista

# %%
dataframes=[]
data_clear=[]
for csv in filenames:
    name_df = re.split(r'[^a-zA-Z0-9\s]', csv)[-2]
    name_df = re.sub(r"\s+", '_', name_df).lower()
    dataframes.append(name_df)
    print(name_df)
    vars()[name_df] = pd.read_excel(csv, index_col=None)
    if vars()[name_df].shape[1]==9:
        vars()[name_df].columns = ["estacion", "fecha", "temperatura", 
        "radiacion", "humedad_relativa", "precipitacion",
         "velocidad_viento", "mojadura", "direccion_viento"]
        vars()[name_df]["presion_atm"]=np.nan
    else:
        vars()[name_df].columns = ["estacion", "fecha", "temperatura", 
        "radiacion", "humedad_relativa", "precipitacion",
         "velocidad_viento", "mojadura", "direccion_viento",
         "presion_atm"]
    #quitando caracteres especiales
    # para qitar caracteres especiales y/o espacios
    vars()[name_df] = vars()[name_df].replace(r'\W+', '', regex=True)
    vars()[name_df] = vars()[name_df].replace(r'\s+', ' ', regex=True)
    vars()[name_df] = vars()[name_df].replace("", np.nan, regex=True)
    vars()[name_df] = vars()[name_df].replace(" ", np.nan, regex=True)
    #formato
    vars()[name_df][[
        'temperatura',
        'radiacion',
        'precipitacion',
        'mojadura'
    ]] = vars()[name_df][[
        'temperatura',
        'radiacion',
        'precipitacion',
        'mojadura'
    ]].apply(pd.to_numeric)
    print('guardando')
    df1=pd.DataFrame(vars()[name_df])
    data_clear.append((df1))
    print(dataframes)
# Out:
# agua_santa
# guardando
# ['agua_santa']
# alamo
# guardando
# ['agua_santa', 'alamo']
# amazonas
# guardando
# ['agua_santa', 'alamo', 'amazonas']
# balsamo
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo']
# bonanza
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza']
# bougambilia
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia']
# cengicana
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana']
# central_izalco
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco']
# chaparrastique
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique']
# chiquirines
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines']
# cocales
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales']
# concepcion
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion']
# copal
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal']
# costa_brava
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava']
# el_carmen
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen']
# el_platanar
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar']
# irlanda
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda']
# la_candelaria
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria']
# la_giralda
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda']
# la_maquina
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina']
# lorena
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena']
# monte_alegre
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre']
# naranjales
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales']
# peten_oficina
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina']
# providencia
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia']
# pueblo_real
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real']
# puyumate
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate']
# san_antonio_del_valle
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle']
# san_clemente
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente']
# san_nicolas
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas']
# san_rafael
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael']
# santa_teresa
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa']
# tehuantepec
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'tehuantepec']
# trinidad_magdalena
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'tehuantepec', 'trinidad_magdalena']
# trinidad
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'tehuantepec', 'trinidad_magdalena', 'trinidad']
# tulula
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'tehuantepec', 'trinidad_magdalena', 'trinidad', 'tulula']
# xoluta
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'tehuantepec', 'trinidad_magdalena', 'trinidad', 'tulula', 'xoluta']
# yepocapa
# guardando
# ['agua_santa', 'alamo', 'amazonas', 'balsamo', 'bonanza', 'bougambilia', 'cengicana', 'central_izalco', 'chaparrastique', 'chiquirines', 'cocales', 'concepcion', 'copal', 'costa_brava', 'el_carmen', 'el_platanar', 'irlanda', 'la_candelaria', 'la_giralda', 'la_maquina', 'lorena', 'monte_alegre', 'naranjales', 'peten_oficina', 'providencia', 'pueblo_real', 'puyumate', 'san_antonio_del_valle', 'san_clemente', 'san_nicolas', 'san_rafael', 'santa_teresa', 'tehuantepec', 'trinidad_magdalena', 'trinidad', 'tulula', 'xoluta', 'yepocapa']

# %%
dfs = pd.concat(data_clear, axis=0, ignore_index=True)
# Out:
#    estacion               fecha  temperatura  radiacion  humedad_relativa  \
# 0  CASSAAGS 2020-06-11 00:15:00          NaN        NaN               NaN
# 1  CASSAAGS 2020-06-11 00:30:00          NaN        NaN               NaN
# 2  CASSAAGS 2020-06-11 00:45:00          NaN        NaN               NaN
# 3  CASSAAGS 2020-06-11 01:00:00          NaN        NaN               NaN
# 4  CASSAAGS 2020-06-11 01:15:00          NaN        NaN               NaN
#
#    precipitacion  velocidad_viento  mojadura  direccion_viento  presion_atm
# 0            NaN               NaN       NaN               NaN          NaN
# 1            NaN               NaN       NaN               NaN          NaN
# 2            NaN               NaN       NaN               NaN          NaN
# 3            NaN               NaN       NaN               NaN          NaN
# 4            NaN               NaN       NaN               NaN          NaN

# %%
dfs['fecha']=dfs.fecha.astype(str)
dfs['fecha']=dfs["fecha"].apply(lambda x: x[0:16])

# %%
"""
Se crea un diccionario con las abreviaturas de los nombres de cada estación

"""

dict_esta= {'cengicana':"CEN-CEN",'tehuantepec':"LUT-TEH", 'balsamo':"PAN-BAL", 'puyumate':"TBU-PUY", 'san_antonio_del_valle':"MAG-SAV", 'amazonas':"SAA-AMA",
             'trinidad':"SDT-TRI", 'irlanda':"TBU-IRL", 'bonanza':"LUT-BON", 'bougambilia':"MAG-BOU", 'naranjales':"PAG-NRJ", 'peten_oficina':"MAT-PEO",
             'costa_brava':"SDT-CBR", 'tulula': "TUL-TLA", 'lorena':"PAG-LOR" , 'san_rafael':"PAN-SRF", 'xoluta':"MAG-XOL", 'san_nicolas':"MAG-SNC",
             'trinidad_magdalena':"MAG-TMG", 'el_platanar':"ICC-PLT",  'la_giralda':"SAA-LGR", 'la_candelaria':"ICC-CDL",  'chiquirines':"ICC-CHI", 'providencia':"MAG-PVD", 
             'alamo':"ICC-ALA", 'cocales':"PAG-COC", 'concepcion':"ICC-CON", 'la_maquina':"SAA-LMQ", 'santa_teresa':"ICC-STA", 'yepocapa':"ICC-YEPO",
             'central_izalco':"CASSA-CIZ",'copal':"CASSA-CPL", 'chaparrastique':"ASSA-CPT", 'el_carmen':"CASSA-ECA", 'san_clemente':"CASSA-SCL", 'agua_santa':"CASSA-AGS",
             'pueblo_real':"ICC-PBR", 'monte_alegre':"ICC-MTA", 'tulula': "TUL-TLA", 
             'SOTZ':"'ICC-SOTZ", 'JOY':"ICC-JOY"
}

# %% [markdown]
# ### Lectura de los datos con control de calidad

# %%
path2 =r'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control/'
filenames2 = glob.glob(path2 + "/*.csv")

# %%
filenames2
# Out:
# ['D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\CEN-CEN.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\ICC-ALA.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\ICC-CDL.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\ICC-CHI.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\ICC-CON.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\ICC-MTA.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\ICC-PBR.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\ICC-PLT.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\ICC-YEPO.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\LUT-BON.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\MAG-BOU.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\MAG-PVD.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\MAG-SAV.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\MAG-SNC.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\MAG-TMG.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\MAG-XOL.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\MAT-PEO.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\PAG-COC.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\PAG-LOR.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\PAG-NRJ.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\PAN-BAL.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\PAN-SRF.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\PUYU.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\SAA-AMA.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\SAA-LGR.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\SAA-LMQ.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\SDT-CBR.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\SDT-TRI.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\TBU-IRL.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\TEHU.csv',
#  'D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/estaciones_control\\TUL-TLA.csv']

# %%
dataframes2=[]
data_clear2=[]
for csv in filenames2:
    name_df = re.split(r'[^a-zA-Z0-9\s]', csv)[-2]
    name_df = re.sub(r"\s+", '_', name_df).lower()
    dataframes2.append(name_df)
    print(name_df)
    vars()[name_df] = pd.read_csv(csv, index_col=None)
    if vars()[name_df].shape[1]==9:
        vars()[name_df].columns = ["estacion", "fecha", "temperatura", 
        "radiacion", "humedad_relativa", "precipitacion",
         "velocidad_viento", "mojadura", "direccion_viento"]
        vars()[name_df]["presion_atm"]=np.nan
    else:
        vars()[name_df].columns = ["estacion", "fecha", "temperatura", 
        "radiacion", "humedad_relativa", "precipitacion",
         "velocidad_viento", "mojadura", "direccion_viento",
         "presion_atm"]
    #quitando caracteres especiales
    # para qitar caracteres especiales y/o espacios
    vars()[name_df] = vars()[name_df].replace(r'\W+', '', regex=True)
    vars()[name_df] = vars()[name_df].replace(r'\s+', ' ', regex=True)
    vars()[name_df] = vars()[name_df].replace("", np.nan, regex=True)
    vars()[name_df] = vars()[name_df].replace(" ", np.nan, regex=True)
    #formato
    vars()[name_df][[
        'temperatura',
        'radiacion',
        'precipitacion',
        'mojadura'
    ]] = vars()[name_df][[
        'temperatura',
        'radiacion',
        'precipitacion',
        'mojadura'
    ]].apply(pd.to_numeric)
    print('guardando')
    df2=pd.DataFrame(vars()[name_df])
    data_clear2.append((df2))
    print(dataframes2)
# Out:
# cen
# guardando
# ['cen']
# ala
# guardando
# ['cen', 'ala']
# cdl
# guardando
# ['cen', 'ala', 'cdl']
# chi
# guardando
# ['cen', 'ala', 'cdl', 'chi']
# con
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con']
# mta
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta']
# pbr
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr']
# plt
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt']
# yepo
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo']
# bon
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon']
# bou
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou']
# pvd
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd']
# sav
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav']
# snc
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc']
# tmg
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg']
# xol
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol']
# peo
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo']
# coc
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc']
# lor
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor']
# nrj
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj']
# bal
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj', 'bal']
# srf
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj', 'bal', 'srf']
# puyu
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj', 'bal', 'srf', 'puyu']
# ama
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj', 'bal', 'srf', 'puyu', 'ama']
# lgr
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj', 'bal', 'srf', 'puyu', 'ama', 'lgr']
# lmq
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj', 'bal', 'srf', 'puyu', 'ama', 'lgr', 'lmq']
# cbr
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj', 'bal', 'srf', 'puyu', 'ama', 'lgr', 'lmq', 'cbr']
# tri
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj', 'bal', 'srf', 'puyu', 'ama', 'lgr', 'lmq', 'cbr', 'tri']
# irl
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj', 'bal', 'srf', 'puyu', 'ama', 'lgr', 'lmq', 'cbr', 'tri', 'irl']
# tehu
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj', 'bal', 'srf', 'puyu', 'ama', 'lgr', 'lmq', 'cbr', 'tri', 'irl', 'tehu']
# tla
# guardando
# ['cen', 'ala', 'cdl', 'chi', 'con', 'mta', 'pbr', 'plt', 'yepo', 'bon', 'bou', 'pvd', 'sav', 'snc', 'tmg', 'xol', 'peo', 'coc', 'lor', 'nrj', 'bal', 'srf', 'puyu', 'ama', 'lgr', 'lmq', 'cbr', 'tri', 'irl', 'tehu', 'tla']

# %%
dfs2 = pd.concat(data_clear2, axis=0, ignore_index=True)
# Out:
#   estacion         fecha  temperatura  radiacion  humedad_relativa  \
# 0   CENCEN  202209120015         23.1        0.0               100
# 1   CENCEN  202209120030         23.1        0.0               100
# 2   CENCEN  202209120045         22.9        0.0               100
# 3   CENCEN  202209120100         22.8        0.0               100
# 4   CENCEN  202209120115         22.7        0.0               100
#
#    precipitacion  velocidad_viento  mojadura  direccion_viento  presion_atm
# 0            0.0               4.4      10.0             342.3          NaN
# 1            0.0               3.5      10.0               8.9          NaN
# 2            0.0               1.4      10.0              60.0          NaN
# 3            0.0               2.2      10.0              51.3          NaN
# 4            0.0               3.2      10.0              43.3          NaN

# %%
"""
Se crea un diccionario con las abreviaturas de los nombres de cada estación

"""

dict_esta= {'CEN':"CENCEN",'TEH':"LUTTEH", 'BAL':"PANBAL", 'PUY':"TBUPUY", 'SAV':"MAGSAV", 'AMA':"SAAAMA",
             'TRI':"SDTTRI", 'IRL':"TBUIRL", 'BON':"LUTBON", 'BOU':"MAGBOU", 'NRJ':"PAGNRJ", 'PEO':"MATPEO",
             'CBR':"SDTCBR", 'TLA': "TULTLA", 'LOR':"PAGLOR" , 'SRF':"PANSRF", 'XOL':"MAGXOL", 'SNC':"MAGSNC",
             'TMG':"MAGTMG", 'PLT':"ICCPLT",  'LGR':"SAALGR", 'CDL':"ICCCDL",  'CHI':"ICCCHI", 'PVD':"MAGPVD", 
             'ALA':"ICCALA", 'COC':"PAGCOC", 'CON':"ICCCON", 'LMQ':"SAALMQ", 'STA':"ICCSTA", 'YEPO':"ICCYEPO",
             'CIZ':"CASSACIZ",'CPL':"CASSACPL", 'CPT':"ASSACPT", 'ECA':"CASSAECA", 'SCL':"CASSASCL", 'AGS':"CASSAAGS",
             'PBR':"ICCPBR", 'MTA':"ICCMTA", 'TUL': "TULTLA", 'NAR': "PAGNRJ", 'LCD':"ICCCDL", 'CASSACPT':"ASSACPT", 'CTB':"SDTCBR",
             'SRAF':"PANSRF",'PUYU':"TBUPUY",'TEHU':"LUTTEH"
}

# %%
"""
Se realiza el reemplazo de las abrevituras a partir del diccionario creado

"""
dfs2.replace({"estacion": dict_esta},inplace=True)

# %%
def formato_fecha(fecha):
    partes_fecha= f"{fecha[:4]}-{fecha[4:6]}-{fecha[6:8]} {fecha[8:10]}:{fecha[10:]}"
    return partes_fecha

# %%
dfs2['fecha'] = dfs2['fecha'].apply(formato_fecha)

# %%
#### Cruzar dataframes

historico  = dfs.merge(dfs2, how='outer', on=['estacion', 'fecha', 'temperatura', 'radiacion', 'humedad_relativa',
       'precipitacion', 'velocidad_viento', 'mojadura', 'direccion_viento',
       'presion_atm'])

# %%
##### Ubicación de la data historica actualizada 
os.chdir('D:/OneDrive - CGIAR/Proyectos/AgriLAC-ICC/ICC/Scrip_bases/historico_actual_2')

# %%
### Guardar cada estacion es un archivo de excel diferente 

for i in historico.estacion.unique():
    
    df3=historico[historico['estacion']==i]
    df3.to_excel(f"{i}.xlsx",index=False)
