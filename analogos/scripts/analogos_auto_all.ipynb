# %% [markdown]
# # cambio de pesos
# aqui se hace el metodo maape, recibe 4 archivos, el de la precipitacion de la estacion, el inicio de lluvia real y los indices de pac y atrlantico

# %%
pwd
# Out:
# 'c:\\Users\\djaimes\\Desktop\\icc'

# %%
import pandas as pd
import numpy as np

# =========================
# FUNCIONES AUXILIARES
# =========================

def calcular_maape(y_true, y_pred):
    """
    Calcula el MAAPE (Mean Arctangent Absolute Percentage Error)
    entre dos listas o arrays numéricos.
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.arctan(np.abs((y_true - y_pred) / (y_true + 1e-6))))

def construir_serie(df, año, mes, var):
    """
    Construye una serie de 6 meses consecutivos terminando en abril del año actual:
    Dic y Nov del año anterior, y Ene a Abr del año actual.
    """
    df = df[['year', 'month', var]]
    meses = [(año-1, 12), (año-1, 11), (año, 1), (año, 2), (año, 3), (año, 4)]
    serie = []
    for y, m in meses:
        valor = df[(df['year'] == y) & (df['month'] == m)]
        if valor.empty:
            return None
        serie.append(valor.iloc[0][var])
    return serie

# =========================
# CARGA DE DATOS
# =========================

ruta_prec = r"c:\\Users\\djaimes\\Desktop\\icc\data\puertosanjose_prec.xlsx" #year-month-prec
#ruta_real = r"c:\\Users\\djaimes\\Desktop\\icc\\data\\start_prec_stations.xlsx"
ruta_real = r"c:\\Users\\djaimes\\Desktop\\icc\data\start_prec_puertosanjose.xlsx"#year-sem_iell
ruta_atl = "c:\\Users\\djaimes\\Desktop\\icc\\data\\oni_atlantico.xlsx"
ruta_pac = "c:\\Users\\djaimes\\Desktop\\icc\\data\\oni_pacifico.xlsx"

prec = pd.read_excel(ruta_prec)
real = pd.read_excel(ruta_real)
atl = pd.read_excel(ruta_atl)
pac = pd.read_excel(ruta_pac)

# Renombrar columnas para estandarizar nombres
atl.rename(columns={'oni': 'atl'}, inplace=True)
pac.rename(columns={'oni': 'pac'}, inplace=True)

# =========================
# CONFIGURACIÓN
# =========================

año_actual = 2019
mes_actual = 4
nombre_estacion = 'puertosanjose'

escenarios = {
    'prec_dom': {'prec': 0.7, 'pac': 0.15, 'atl': 0.15},
    'enso_dom': {'prec': 0.3, 'pac': 0.5, 'atl': 0.2},
    'enso_prec': {'prec': 0.4, 'pac': 0.4, 'atl': 0.2},
    'neutro': {'prec': 0.33, 'pac': 0.33, 'atl': 0.33},
    'atl_dom': {'prec': 0.3, 'pac': 0.2, 'atl': 0.5},
}

# =========================
# CÁLCULO DE SERIES ACTUALES
# =========================

serie_actual_prec = construir_serie(prec, año_actual, mes_actual, 'prec')
serie_actual_atl = construir_serie(atl, año_actual, mes_actual, 'atl')
serie_actual_pac = construir_serie(pac, año_actual, mes_actual, 'pac')

if None in [serie_actual_prec, serie_actual_atl, serie_actual_pac]:
    print("No hay suficientes datos para calcular la serie actual.")
    exit()

# =========================
# COMPARACIÓN CON AÑOS ANTERIORES
# =========================

resultados = []

for año_pasado in range(año_actual-1, prec['year'].min()-1, -1):
    serie_ant_prec = construir_serie(prec, año_pasado, mes_actual, 'prec')
    serie_ant_atl = construir_serie(atl, año_pasado, mes_actual, 'atl')
    serie_ant_pac = construir_serie(pac, año_pasado, mes_actual, 'pac')

    if None in [serie_ant_prec, serie_ant_atl, serie_ant_pac]:
        continue

    maape_prec = calcular_maape(serie_actual_prec, serie_ant_prec)
    maape_atl = calcular_maape(serie_actual_atl, serie_ant_atl)
    maape_pac = calcular_maape(serie_actual_pac, serie_ant_pac)

    #real = real[real.estacion==nombre_estacion]
    fila_real = real[real['year'] == año_pasado]
    semana_inicio = int(fila_real['sem_iell'].values[0]) if not fila_real.empty else np.nan

    resultados.append({
        'año': año_pasado,
        'maape_prec': maape_prec,
        'maape_atl': maape_atl,
        'maape_pac': maape_pac,
        'sem_iell': semana_inicio
    })

if len(resultados) < 8:
    print("No hay suficientes años anteriores con datos completos para comparar.")
    exit()

df_resultados = pd.DataFrame(resultados)

# =========================
# CÁLCULO DE ESCENARIOS
# =========================

df_final = pd.DataFrame()

for nombre_esc, pesos in escenarios.items():
    df_esc = df_resultados.copy()
    df_esc['maape_esc'] = (
        pesos['prec'] * df_esc['maape_prec'] +
        pesos['atl'] * df_esc['maape_atl'] +
        pesos['pac'] * df_esc['maape_pac']
    )
    df_esc = df_esc.sort_values('maape_esc').reset_index(drop=True)
    df_esc['escenario'] = nombre_esc
    df_esc['estacion'] = nombre_estacion

    # Calcular top 5 y semanas resumen
    top5 = df_esc.head(5)

    #  Imprimir top 5 como validación
    print(f"\n Top 5 años análogos para el escenario '{nombre_esc}':")
    print(top5[['año', 'maape_esc', 'sem_iell']])

    semana_prom = top5['sem_iell'].mean()
    pesos_pond = np.array([0.5, 0.25, 0.1, 0.075, 0.075])
    semana_pond = np.sum(top5['sem_iell'].values * pesos_pond)

    df_final = pd.concat([df_final, pd.DataFrame({
        'año_analizado': [año_actual],
        'mes_analizado': [mes_actual],
        'escenario': [nombre_esc],
        'estacion': [nombre_estacion],
        'semana_promedio': [semana_prom],
        'semana_ponderada': [semana_pond]
    })], ignore_index=True)

# =========================
# RESULTADO FINAL
# =========================

print("\n Resumen de resultados por escenario:")
print(df_final)
# Out:
#  Top 5 años análogos para el escenario 'prec_dom':
#     año  maape_esc  sem_iell
# 0  2002   0.478872        30
# 1  2004   0.572054        27
# 2  2001   0.636853        30
# 3  2009   0.637472        27
# 4  2015   0.703556        33
#
#  Top 5 años análogos para el escenario 'enso_dom':
#     año  maape_esc  sem_iell
# 0  2015   0.522159        33
# 1  2004   0.576889        27
# 2  2003   0.589288        30
# 3  2005   0.638217        27
# 4  2007   0.656376        31
#
#  Top 5 años análogos para el escenario 'enso_prec':
#     año  maape_esc  sem_iell
# 0  2015   0.576593        33
# 1  2004   0.578731        27
# 2  2003   0.626008        30
# 3  2002   0.631103        30
# 4  2007   0.708743        31
#
#  Top 5 años análogos para el escenario 'neutro':
#     año  maape_esc  sem_iell
# 0  2004   0.603946        27
# 1  2015   0.630836        33
# 2  2003   0.649115        30
# 3  2002   0.671058        30
# 4  2007   0.715385        31
#
#  Top 5 años análogos para el escenario 'atl_dom':
#     año  maape_esc  sem_iell
# 0  2004   0.650113        27
# 1  2003   0.711111        30
# 2  2002   0.711761        30
# 3  2015   0.740194        33
# 4  2007   0.766130        31
#
#  Resumen de resultados por escenario:
#    año_analizado  mes_analizado  escenario       estacion  semana_promedio  \
# 0           2019              4   prec_dom  puertosanjose             29.4
# 1           2019              4   enso_dom  puertosanjose             29.6
# 2           2019              4  enso_prec  puertosanjose             30.2
# 3           2019              4     neutro  puertosanjose             30.2
# 4           2019              4    atl_dom  puertosanjose             30.2
#
#    semana_ponderada
# 0            29.250
# 1            30.600
# 2            30.825
# 3            29.325
# 4            28.800

# %%
df_final.año_analizado.value_counts()
# Out:
# año_analizado
# 2019    5
# Name: count, dtype: int64

# %%
# =========================
# EVALUACIÓN CONTRA DATO REAL
# =========================

# Obtener semana real del año analizado
semana_real = real.loc[real['year'] == año_actual, 'sem_iell']
if semana_real.empty:
    print(f" No se encontró 'sem_iell' real para el año {año_actual}")
    df_final['sem_iell_real'] = np.nan
    df_final['error_abs_prom'] = np.nan
    df_final['error_abs_pond'] = np.nan
else:
    sem_real = int(semana_real.values[0])
    df_final['sem_iell_real'] = sem_real
    df_final['error_abs_prom'] = (df_final['semana_promedio'].round() - sem_real).abs()
    df_final['error_abs_pond'] = (df_final['semana_ponderada'].round() - sem_real).abs()

df_final
# Out:
#    año_analizado  mes_analizado  escenario       estacion  semana_promedio  \
# 0           2019              4   prec_dom  puertosanjose             29.4
# 1           2019              4   enso_dom  puertosanjose             29.6
# 2           2019              4  enso_prec  puertosanjose             30.2
# 3           2019              4     neutro  puertosanjose             30.2
# 4           2019              4    atl_dom  puertosanjose             30.2
#
#    semana_ponderada  sem_iell_real  error_abs_prom  error_abs_pond
# 0            29.250             25             4.0             4.0
# 1            30.600             25             5.0             6.0
# 2            30.825             25             5.0             6.0
# 3            29.325             25             5.0             4.0
# 4            28.800             25             5.0             4.0

# %%
todos_los_resultados = pd.DataFrame()

for año_actual in range(2023, 2000, -1):  # desde 2020 hasta 2010
    print(f"Procesando año: {año_actual}")

    # Construir series actuales
    serie_actual_prec = construir_serie(prec, año_actual, mes_actual, 'prec')
    serie_actual_atl = construir_serie(atl, año_actual, mes_actual, 'atl')
    serie_actual_pac = construir_serie(pac, año_actual, mes_actual, 'pac')

    if None in [serie_actual_prec, serie_actual_atl, serie_actual_pac]:
        print(f" Datos insuficientes para año {año_actual}, se omite.")
        continue

    resultados = []

    for año_pasado in range(año_actual-1, prec['year'].min()-1, -1):
        serie_ant_prec = construir_serie(prec, año_pasado, mes_actual, 'prec')
        serie_ant_atl = construir_serie(atl, año_pasado, mes_actual, 'atl')
        serie_ant_pac = construir_serie(pac, año_pasado, mes_actual, 'pac')

        if None in [serie_ant_prec, serie_ant_atl, serie_ant_pac]:
            continue

        maape_prec = calcular_maape(serie_actual_prec, serie_ant_prec)
        maape_atl = calcular_maape(serie_actual_atl, serie_ant_atl)
        maape_pac = calcular_maape(serie_actual_pac, serie_ant_pac)

        fila_real = real[real['year'] == año_pasado]
        semana_inicio = int(fila_real['sem_iell'].values[0]) if not fila_real.empty else np.nan

        resultados.append({
            'año': año_pasado,
            'maape_prec': maape_prec,
            'maape_atl': maape_atl,
            'maape_pac': maape_pac,
            'sem_iell': semana_inicio
        })

    if len(resultados) < 8:
        print(f" Menos de 8 años comparables para {año_actual}. Se omite.")
        continue

    df_resultados = pd.DataFrame(resultados)
    df_final = pd.DataFrame()

    for nombre_esc, pesos in escenarios.items():
        df_esc = df_resultados.copy()
        df_esc['maape_esc'] = (
            pesos['prec'] * df_esc['maape_prec'] +
            pesos['atl'] * df_esc['maape_atl'] +
            pesos['pac'] * df_esc['maape_pac']
        )
        df_esc = df_esc.sort_values('maape_esc').reset_index(drop=True)
        df_esc['escenario'] = nombre_esc
        df_esc['estacion'] = nombre_estacion

        top5 = df_esc.head(5)
        print(f"\n Top 5 años análogos para el escenario '{nombre_esc}' en {año_actual}:")
        print(top5[['año', 'maape_esc', 'sem_iell']])

        semana_prom = top5['sem_iell'].mean()
        pesos_pond = np.array([0.5, 0.25, 0.1, 0.075, 0.075])
        semana_pond = np.sum(top5['sem_iell'].values * pesos_pond)

        df_final = pd.concat([df_final, pd.DataFrame({
            'año_analizado': [año_actual],
            'mes_analizado': [mes_actual],
            'escenario': [nombre_esc],
            'estacion': [nombre_estacion],
            'semana_promedio': [semana_prom],
            'semana_ponderada': [semana_pond]
        })], ignore_index=True)

    # Calcular error contra semana real
    semana_real = real.loc[real['year'] == año_actual, 'sem_iell']
    if semana_real.empty:
        print(f" No se encontró semana real para {año_actual}.")
        df_final['sem_iell_real'] = np.nan
        df_final['error_abs_prom'] = np.nan
        df_final['error_abs_pond'] = np.nan
    else:
        sem_real = int(semana_real.values[0])
        df_final['sem_iell_real'] = sem_real
        df_final['error_abs_prom'] = (df_final['semana_promedio'].round() - sem_real).abs()
        df_final['error_abs_pond'] = (df_final['semana_ponderada'].round() - sem_real).abs()

    todos_los_resultados = pd.concat([todos_los_resultados, df_final], ignore_index=True)

# =========================
# RESULTADO TOTAL
# =========================

print("\n Resultado final para todos los años:")
print(todos_los_resultados)

todos_los_resultados.to_excel("data/resultados_analogos_puertosanjose.xlsx", index=False)
# Out:
# Procesando año: 2023
#  Datos insuficientes para año 2023, se omite.
# Procesando año: 2022
#  Datos insuficientes para año 2022, se omite.
# Procesando año: 2021
#  Datos insuficientes para año 2021, se omite.
# Procesando año: 2020
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2020:
#     año  maape_esc  sem_iell
# 0  2004   0.474138        27
# 1  2019   0.522482        25
# 2  2005   0.611291        27
# 3  2015   0.612306        33
# 4  2002   0.619805        30
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2020:
#     año  maape_esc  sem_iell
# 0  2004   0.407476        27
# 1  2015   0.482992        33
# 2  2005   0.489094        27
# 3  2019   0.585562        25
# 4  2002   0.672631        30
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2020:
#     año  maape_esc  sem_iell
# 0  2004   0.430357        27
# 1  2015   0.517977        33
# 2  2005   0.523534        27
# 3  2019   0.569681        25
# 4  2002   0.658934        30
#
#  Top 5 años análogos para el escenario 'neutro' en 2020:
#     año  maape_esc  sem_iell
# 0  2004   0.476586        27
# 1  2015   0.517762        33
# 2  2005   0.536649        27
# 3  2019   0.573288        25
# 4  2002   0.656212        30
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2020:
#     año  maape_esc  sem_iell
# 0  2015   0.546754        33
# 1  2004   0.556643        27
# 2  2005   0.582458        27
# 3  2019   0.582885        25
# 4  2007   0.645609        31
#  No se encontró semana real para 2020.
# Procesando año: 2019
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2019:
#     año  maape_esc  sem_iell
# 0  2002   0.478872        30
# 1  2004   0.572054        27
# 2  2001   0.636853        30
# 3  2009   0.637472        27
# 4  2015   0.703556        33
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2019:
#     año  maape_esc  sem_iell
# 0  2015   0.522159        33
# 1  2004   0.576889        27
# 2  2003   0.589288        30
# 3  2005   0.638217        27
# 4  2007   0.656376        31
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2019:
#     año  maape_esc  sem_iell
# 0  2015   0.576593        33
# 1  2004   0.578731        27
# 2  2003   0.626008        30
# 3  2002   0.631103        30
# 4  2007   0.708743        31
#
#  Top 5 años análogos para el escenario 'neutro' en 2019:
#     año  maape_esc  sem_iell
# 0  2004   0.603946        27
# 1  2015   0.630836        33
# 2  2003   0.649115        30
# 3  2002   0.671058        30
# 4  2007   0.715385        31
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2019:
#     año  maape_esc  sem_iell
# 0  2004   0.650113        27
# 1  2003   0.711111        30
# 2  2002   0.711761        30
# 3  2015   0.740194        33
# 4  2007   0.766130        31
# Procesando año: 2018
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2018:
#     año  maape_esc  sem_iell
# 0  2008   0.318919        30
# 1  1999   0.528891        24
# 2  2012   0.529664        29
# 3  2011   0.593388        28
# 4  2001   0.597355        30
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2018:
#     año  maape_esc  sem_iell
# 0  2012   0.396727        29
# 1  2006   0.475305        27
# 2  2009   0.489159        27
# 3  2001   0.503423        30
# 4  2008   0.537804        30
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2018:
#     año  maape_esc  sem_iell
# 0  2012   0.439284        29
# 1  2008   0.484920        30
# 2  2009   0.529503        27
# 3  2001   0.533570        30
# 4  2006   0.550142        27
#
#  Top 5 años análogos para el escenario 'neutro' en 2018:
#     año  maape_esc  sem_iell
# 0  2012   0.505252        29
# 1  2008   0.534379        30
# 2  2006   0.562617        27
# 3  2001   0.578713        30
# 4  2009   0.599728        27
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2018:
#     año  maape_esc  sem_iell
# 0  2008   0.581905        30
# 1  2012   0.620475        29
# 2  2006   0.628415        27
# 3  1999   0.645310        24
# 4  2001   0.663368        30
# Procesando año: 2017
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2017:
#     año  maape_esc  sem_iell
# 0  2002   0.629341        30
# 1  2013   0.771170        30
# 2  2001   0.774913        30
# 3  2009   0.784954        27
# 4  2006   0.814137        27
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2017:
#     año  maape_esc  sem_iell
# 0  2002   0.512041        30
# 1  2001   0.792489        30
# 2  2013   0.807185        30
# 3  2009   0.814163        27
# 4  2014   0.830476        26
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2017:
#     año  maape_esc  sem_iell
# 0  2002   0.543017        30
# 1  2001   0.789807        30
# 2  2013   0.797672        30
# 3  2009   0.805201        27
# 4  2006   0.855093        27
#
#  Top 5 años análogos para el escenario 'neutro' en 2017:
#     año  maape_esc  sem_iell
# 0  2002   0.534576        30
# 1  2009   0.785534        27
# 2  2013   0.790596        30
# 3  2001   0.801751        30
# 4  2014   0.815796        26
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2017:
#     año  maape_esc  sem_iell
# 0  2002   0.551663        30
# 1  2009   0.774323        27
# 2  2014   0.788928        26
# 3  2003   0.793704        30
# 4  2013   0.794963        30
# Procesando año: 2016
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2016:
#     año  maape_esc  sem_iell
# 0  2002   0.483869        30
# 1  2009   0.510013        27
# 2  2003   0.591517        30
# 3  2010   0.608824        24
# 4  2007   0.621424        31
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2016:
#     año  maape_esc  sem_iell
# 0  2010   0.602112        24
# 1  2015   0.604649        33
# 2  2003   0.609099        30
# 3  2002   0.642487        30
# 4  2005   0.663780        27
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2016:
#     año  maape_esc  sem_iell
# 0  2002   0.601818        30
# 1  2003   0.605830        30
# 2  2015   0.610261        33
# 3  2010   0.612797        24
# 4  2007   0.652730        31
#
#  Top 5 años análogos para el escenario 'neutro' en 2016:
#     año  maape_esc  sem_iell
# 0  2015   0.610720        33
# 1  2002   0.611927        30
# 2  2003   0.613817        30
# 3  2007   0.645999        31
# 4  2009   0.674277        27
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2016:
#     año  maape_esc  sem_iell
# 0  2014   0.610144        26
# 1  2002   0.618136        30
# 2  2015   0.627980        33
# 3  2003   0.636117        30
# 4  2007   0.646561        31
# Procesando año: 2015
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2015:
#     año  maape_esc  sem_iell
# 0  2009   0.454142        27
# 1  2002   0.486014        30
# 2  2003   0.556324        30
# 3  2011   0.564046        28
# 4  2005   0.564690        27
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2015:
#     año  maape_esc  sem_iell
# 0  2005   0.405027        27
# 1  2003   0.579049        30
# 2  2004   0.583198        27
# 3  2002   0.629347        30
# 4  2007   0.668960        31
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2015:
#     año  maape_esc  sem_iell
# 0  2005   0.449762        27
# 1  2003   0.576353        30
# 2  2002   0.589319        30
# 3  2004   0.630860        27
# 4  2009   0.703813        27
#
#  Top 5 años análogos para el escenario 'neutro' en 2015:
#     año  maape_esc  sem_iell
# 0  2005   0.466636        27
# 1  2002   0.565546        30
# 2  2003   0.603893        30
# 3  2004   0.612463        27
# 4  2007   0.661250        31
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2015:
#     año  maape_esc  sem_iell
# 0  2005   0.520701        27
# 1  2002   0.528669        30
# 2  2000   0.618535        26
# 3  2004   0.627217        27
# 4  2007   0.640439        31
# Procesando año: 2014
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2014:
#     año  maape_esc  sem_iell
# 0  2004   0.622706        27
# 1  2002   0.636934        30
# 2  2009   0.641181        27
# 3  2001   0.686764        30
# 4  2012   0.694218        29
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2014:
#     año  maape_esc  sem_iell
# 0  2002   0.668533        30
# 1  2013   0.702437        30
# 2  2001   0.741651        30
# 3  2009   0.796627        27
# 4  2012   0.842826        29
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2014:
#     año  maape_esc  sem_iell
# 0  2002   0.658552        30
# 1  2001   0.728309        30
# 2  2013   0.744673        30
# 3  2009   0.755685        27
# 4  2004   0.801739        27
#
#  Top 5 años análogos para el escenario 'neutro' en 2014:
#     año  maape_esc  sem_iell
# 0  2002   0.636578        30
# 1  2001   0.733840        30
# 2  2013   0.751329        30
# 3  2009   0.753179        27
# 4  2004   0.765594        27
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2014:
#     año  maape_esc  sem_iell
# 0  2002   0.618587        30
# 1  2007   0.691877        31
# 2  2004   0.703324        27
# 3  2000   0.740455        26
# 4  2009   0.746693        27
# Procesando año: 2013
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2013:
#     año  maape_esc  sem_iell
# 0  2006   0.580805        27
# 1  2009   0.597253        27
# 2  2002   0.608715        30
# 3  2001   0.639785        30
# 4  2003   0.690289        30
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2013:
#     año  maape_esc  sem_iell
# 0  2001   0.649982        30
# 1  2009   0.733180        27
# 2  2006   0.735229        27
# 3  2002   0.764413        30
# 4  2012   0.946985        29
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2013:
#     año  maape_esc  sem_iell
# 0  2001   0.648299        30
# 1  2006   0.693463        27
# 2  2009   0.699509        27
# 3  2002   0.726463        30
# 4  2003   0.882024        30
#
#  Top 5 años análogos para el escenario 'neutro' en 2013:
#     año  maape_esc  sem_iell
# 0  2001   0.652080        30
# 1  2006   0.680722        27
# 2  2009   0.718013        27
# 3  2002   0.754534        30
# 4  2003   0.878052        30
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2013:
#     año  maape_esc  sem_iell
# 0  2006   0.659384        27
# 1  2001   0.670785        30
# 2  2009   0.740626        27
# 3  2002   0.787797        30
# 4  2003   0.858515        30
# Procesando año: 2012
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2012:
#     año  maape_esc  sem_iell
# 0  2009   0.538858        27
# 1  2001   0.591940        30
# 2  2011   0.598140        28
# 3  1999   0.616531        24
# 4  2002   0.674934        30
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2012:
#     año  maape_esc  sem_iell
# 0  2009   0.435127        27
# 1  2001   0.490181        30
# 2  2006   0.501180        27
# 3  2011   0.597559        28
# 4  1999   0.621490        24
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2012:
#     año  maape_esc  sem_iell
# 0  2009   0.468014        27
# 1  2001   0.521267        30
# 2  2006   0.568579        27
# 3  2011   0.603355        28
# 4  1999   0.620998        24
#
#  Top 5 años análogos para el escenario 'neutro' en 2012:
#     año  maape_esc  sem_iell
# 0  2009   0.515069        27
# 1  2001   0.555165        30
# 2  2006   0.609774        27
# 3  1999   0.623014        24
# 4  2011   0.653168        28
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2012:
#     año  maape_esc  sem_iell
# 0  2009   0.602037        27
# 1  2001   0.625699        30
# 2  1999   0.639446        24
# 3  2008   0.698143        30
# 4  2004   0.707944        27
# Procesando año: 2011
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2011:
#     año  maape_esc  sem_iell
# 0  2009   0.371579        27
# 1  1999   0.504457        24
# 2  2002   0.531287        30
# 3  2003   0.535563        30
# 4  2000   0.606763        26
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2011:
#     año  maape_esc  sem_iell
# 0  1999   0.385283        24
# 1  2009   0.436580        27
# 2  2000   0.437362        26
# 3  2008   0.479967        30
# 4  2006   0.554908        27
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2011:
#     año  maape_esc  sem_iell
# 0  2009   0.422728        27
# 1  1999   0.423278        24
# 2  2000   0.488486        26
# 3  2008   0.531915        30
# 4  2006   0.573913        27
#
#  Top 5 años análogos para el escenario 'neutro' en 2011:
#     año  maape_esc  sem_iell
# 0  2009   0.452973        27
# 1  1999   0.480577        24
# 2  2000   0.542512        26
# 3  2008   0.566266        30
# 4  2002   0.605338        30
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2011:
#     año  maape_esc  sem_iell
# 0  2009   0.494149        27
# 1  1999   0.582121        24
# 2  2002   0.591732        30
# 3  2003   0.611178        30
# 4  2000   0.647936        26
# Procesando año: 2010
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2010:
#     año  maape_esc  sem_iell
# 0  2007   0.630025        31
# 1  2002   0.630695        30
# 2  2009   0.635793        27
# 3  2003   0.673556        30
# 4  2005   0.680372        27
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2010:
#     año  maape_esc  sem_iell
# 0  2003   0.587149        30
# 1  2005   0.601530        27
# 2  2007   0.688599        31
# 3  2004   0.731777        27
# 4  2002   0.741807        30
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2010:
#     año  maape_esc  sem_iell
# 0  2003   0.614599        30
# 1  2005   0.628351        27
# 2  2007   0.678861        31
# 3  2002   0.717648        30
# 4  2004   0.744717        27
#
#  Top 5 años análogos para el escenario 'neutro' en 2010:
#     año  maape_esc  sem_iell
# 0  2003   0.652091        30
# 1  2005   0.679456        27
# 2  2007   0.730303        31
# 3  2002   0.764632        30
# 4  2004   0.784894        27
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2010:
#     año  maape_esc  sem_iell
# 0  2003   0.727501        30
# 1  2005   0.772190        27
# 2  2009   0.804627        27
# 3  2007   0.806335        31
# 4  2002   0.828660        30
# Procesando año: 2009
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2009:
#     año  maape_esc  sem_iell
# 0  2006   0.422220        27
# 1  2002   0.535638        30
# 2  2001   0.647532        30
# 3  2003   0.751806        30
# 4  1999   0.767724        24
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2009:
#     año  maape_esc  sem_iell
# 0  2006   0.365790        27
# 1  2001   0.504151        30
# 2  2002   0.706881        30
# 3  1999   0.834083        24
# 4  2000   0.870582        26
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2009:
#     año  maape_esc  sem_iell
# 0  2006   0.391764        27
# 1  2001   0.552362        30
# 2  2002   0.669617        30
# 3  1999   0.819883        24
# 4  2000   0.856009        26
#
#  Top 5 años análogos para el escenario 'neutro' en 2009:
#     año  maape_esc  sem_iell
# 0  2006   0.496015        27
# 1  2001   0.645598        30
# 2  2002   0.746086        30
# 3  1999   0.846297        24
# 4  2003   0.852869        30
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2009:
#     año  maape_esc  sem_iell
# 0  2006   0.650590        27
# 1  2001   0.800922        30
# 2  2003   0.836651        30
# 3  2002   0.839998        30
# 4  1999   0.891448        24
# Procesando año: 2008
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2008:
#     año  maape_esc  sem_iell
# 0  1999   0.457447        24
# 1  2001   0.647630        30
# 2  2003   0.691181        30
# 3  2002   0.692865        30
# 4  2004   0.712984        27
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2008:
#     año  maape_esc  sem_iell
# 0  1999   0.308304        24
# 1  2000   0.458804        26
# 2  2001   0.647618        30
# 3  2006   0.719923        27
# 4  2002   0.740907        30
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2008:
#     año  maape_esc  sem_iell
# 0  1999   0.352880        24
# 1  2000   0.533269        26
# 2  2001   0.652592        30
# 3  2002   0.729489        30
# 4  2006   0.762185        27
#
#  Top 5 años análogos para el escenario 'neutro' en 2008:
#     año  maape_esc  sem_iell
# 0  1999   0.396914        24
# 1  2000   0.574601        26
# 2  2001   0.695272        30
# 3  2002   0.735988        30
# 4  2003   0.791678        30
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2008:
#     año  maape_esc  sem_iell
# 0  1999   0.483264        24
# 1  2000   0.676557        26
# 2  2002   0.755129        30
# 3  2001   0.766912        30
# 4  2003   0.790519        30
# Procesando año: 2007
#
#  Top 5 años análogos para el escenario 'prec_dom' en 2007:
#     año  maape_esc  sem_iell
# 0  2002   0.627359        30
# 1  2004   0.709893        27
# 2  2001   0.786945        30
# 3  2005   0.804446        27
# 4  2003   0.810712        30
#
#  Top 5 años análogos para el escenario 'enso_dom' en 2007:
#     año  maape_esc  sem_iell
# 0  2004   0.712848        27
# 1  2003   0.768758        30
# 2  2005   0.768787        27
# 3  2002   0.799248        30
# 4  2001   0.876272        30
#
#  Top 5 años análogos para el escenario 'enso_prec' en 2007:
#     año  maape_esc  sem_iell
# 0  2004   0.713234        27
# 1  2002   0.755745        30
# 2  2005   0.779689        27
# 3  2003   0.781375        30
# 4  2001   0.853011        30
#
#  Top 5 años análogos para el escenario 'neutro' en 2007:
#     año  maape_esc  sem_iell
# 0  2004   0.717725        27
# 1  2002   0.771296        30
# 2  2005   0.785684        27
# 3  2003   0.787708        30
# 4  2001   0.850024        30
#
#  Top 5 años análogos para el escenario 'atl_dom' en 2007:
#     año  maape_esc  sem_iell
# 0  2004   0.739843        27
# 1  2002   0.786512        30
# 2  2005   0.816484        27
# 3  2003   0.819836        30
# 4  2001   0.853978        30
# Procesando año: 2006
#  Menos de 8 años comparables para 2006. Se omite.
# Procesando año: 2005
#  Menos de 8 años comparables para 2005. Se omite.
# Procesando año: 2004
#  Menos de 8 años comparables para 2004. Se omite.
# Procesando año: 2003
#  Menos de 8 años comparables para 2003. Se omite.
# Procesando año: 2002
#  Menos de 8 años comparables para 2002. Se omite.
# Procesando año: 2001
#  Menos de 8 años comparables para 2001. Se omite.
#
#  Resultado final para todos los años:
#     año_analizado  mes_analizado  escenario       estacion  semana_promedio  \
# 0            2020              4   prec_dom  puertosanjose             28.4
# 1            2020              4   enso_dom  puertosanjose             28.4
# 2            2020              4  enso_prec  puertosanjose             28.4
# 3            2020              4     neutro  puertosanjose             28.4
# 4            2020              4    atl_dom  puertosanjose             28.6
# ..            ...            ...        ...            ...              ...
# 65           2007              4   prec_dom  puertosanjose             28.8
# 66           2007              4   enso_dom  puertosanjose             28.8
# 67           2007              4  enso_prec  puertosanjose             28.8
# 68           2007              4     neutro  puertosanjose             28.8
# 69           2007              4    atl_dom  puertosanjose             28.8
#
#     semana_ponderada  sem_iell_real  error_abs_prom  error_abs_pond
# 0             27.175            NaN             NaN             NaN
# 1             28.575            NaN             NaN             NaN
# 2             28.575            NaN             NaN             NaN
# 3             28.575            NaN             NaN             NaN
# 4             30.150            NaN             NaN             NaN
# ..               ...            ...             ...             ...
# 65            29.025           31.0             2.0             2.0
# 66            28.200           31.0             2.0             3.0
# 67            28.200           31.0             2.0             3.0
# 68            28.200           31.0             2.0             3.0
# 69            28.200           31.0             2.0             3.0
#
# [70 rows x 9 columns]

# %%
todos_los_resultados.año_analizado.max()
# Out:
# np.int64(2020)
