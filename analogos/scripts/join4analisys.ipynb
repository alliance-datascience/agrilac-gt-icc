# %% [markdown]
# # cambio de pesos
# aqui se hace el metodo maape, recibe 4 archivos, el de la precipitacion de la estacion, el inicio de lluvia real y los indices de pac y atrlantico

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
folder= Path("data")
pattern = "resultados_analogos_*.xlsx"
df_list=[]

# %%
for file in folder.glob(pattern):
    print(file)
    df=pd.read_excel(file)
    df_list.append(df)
# Out:
# data\resultados_analogos_cengicana.xlsx
# data\resultados_analogos_laborovalle.xlsx
# data\resultados_analogos_lafragua.xlsx
# data\resultados_analogos_puertosanjose.xlsx

# %%
stations= pd.concat(df_list, ignore_index=True)
iell = pd.read_excel("data/start_prec_stations.xlsx")

# %%
stations
# Out:
#      año_analizado  mes_analizado  escenario       estacion  semana_promedio  \
# 0             2023              4   prec_dom      cengicana             21.4
# 1             2023              4   enso_dom      cengicana             22.6
# 2             2023              4  enso_prec      cengicana             22.6
# 3             2023              4     neutro      cengicana             21.8
# 4             2023              4    atl_dom      cengicana             21.6
# ..             ...            ...        ...            ...              ...
# 290           2007              4   prec_dom  puertosanjose             28.8
# 291           2007              4   enso_dom  puertosanjose             28.8
# 292           2007              4  enso_prec  puertosanjose             28.8
# 293           2007              4     neutro  puertosanjose             28.8
# 294           2007              4    atl_dom  puertosanjose             28.8
#
#      semana_ponderada  sem_iell_real  error_abs_prom  error_abs_pond
# 0              20.100           22.0             1.0             2.0
# 1              23.200           22.0             1.0             1.0
# 2              23.100           22.0             1.0             1.0
# 3              23.300           22.0             0.0             1.0
# 4              23.050           22.0             0.0             1.0
# ..                ...            ...             ...             ...
# 290            29.025           31.0             2.0             2.0
# 291            28.200           31.0             2.0             3.0
# 292            28.200           31.0             2.0             3.0
# 293            28.200           31.0             2.0             3.0
# 294            28.200           31.0             2.0             3.0
#
# [295 rows x 9 columns]

# %%
iell.rename(columns={'estacion':'station'}, inplace=True)
iell
# Out:
#        station  year  sem_iell
# 0     lafragua  1980        41
# 1     lafragua  1981        33
# 2     lafragua  1982        35
# 3     lafragua  1983        36
# 4     lafragua  1984        32
# ..         ...   ...       ...
# 150  cengicana  2001        25
# 151  cengicana  2000        26
# 152  cengicana  1999        23
# 153  cengicana  1998        31
# 154  cengicana  1997        28
#
# [155 rows x 3 columns]

# %%
iell.station.unique()
# Out:
# array(['lafragua', 'laborovalle', 'puertosanjose', 'cengicana'],
#       dtype=object)

# %%
stations.rename(columns={'año_analizado':'year', 'mes_analizado':'month','estacion':'station'}, inplace=True)
stations.head()
# Out:
#    year  month  escenario    station  semana_promedio  semana_ponderada  \
# 0  2023      4   prec_dom  cengicana             21.4             20.10
# 1  2023      4   enso_dom  cengicana             22.6             23.20
# 2  2023      4  enso_prec  cengicana             22.6             23.10
# 3  2023      4     neutro  cengicana             21.8             23.30
# 4  2023      4    atl_dom  cengicana             21.6             23.05
#
#    sem_iell_real  error_abs_prom  error_abs_pond
# 0           22.0             1.0             2.0
# 1           22.0             1.0             1.0
# 2           22.0             1.0             1.0
# 3           22.0             0.0             1.0
# 4           22.0             0.0             1.0

# %%
stations.station.unique()
# Out:
# array(['cengicana', 'laborovalle', 'lafragua', 'puertosanjose'],
#       dtype=object)

# %%
all_info= stations.merge(iell, how ='outer', on=['year', 'station'],indicator=True)
all_info
# Out:
#      year  month  escenario      station  semana_promedio  semana_ponderada  \
# 0    1980    NaN        NaN  laborovalle              NaN               NaN
# 1    1980    NaN        NaN     lafragua              NaN               NaN
# 2    1981    NaN        NaN  laborovalle              NaN               NaN
# 3    1981    NaN        NaN     lafragua              NaN               NaN
# 4    1982    NaN        NaN  laborovalle              NaN               NaN
# ..    ...    ...        ...          ...              ...               ...
# 417  2023    4.0   enso_dom    cengicana             22.6             23.20
# 418  2023    4.0  enso_prec    cengicana             22.6             23.10
# 419  2023    4.0     neutro    cengicana             21.8             23.30
# 420  2023    4.0    atl_dom    cengicana             21.6             23.05
# 421  2024    NaN        NaN    cengicana              NaN               NaN
#
#      sem_iell_real  error_abs_prom  error_abs_pond  sem_iell      _merge
# 0              NaN             NaN             NaN      33.0  right_only
# 1              NaN             NaN             NaN      41.0  right_only
# 2              NaN             NaN             NaN      30.0  right_only
# 3              NaN             NaN             NaN      33.0  right_only
# 4              NaN             NaN             NaN      28.0  right_only
# ..             ...             ...             ...       ...         ...
# 417           22.0             1.0             1.0      22.0        both
# 418           22.0             1.0             1.0      22.0        both
# 419           22.0             0.0             1.0      22.0        both
# 420           22.0             0.0             1.0      22.0        both
# 421            NaN             NaN             NaN      23.0  right_only
#
# [422 rows x 11 columns]

# %%
all_info[all_info['_merge']=='both']
# Out:
#      year  month  escenario    station  semana_promedio  semana_ponderada  \
# 91   2007    4.0   prec_dom  cengicana             23.6             23.50
# 92   2007    4.0   enso_dom  cengicana             23.6             23.50
# 93   2007    4.0  enso_prec  cengicana             23.6             23.50
# 94   2007    4.0     neutro  cengicana             23.6             23.80
# 95   2007    4.0    atl_dom  cengicana             23.6             23.80
# ..    ...    ...        ...        ...              ...               ...
# 416  2023    4.0   prec_dom  cengicana             21.4             20.10
# 417  2023    4.0   enso_dom  cengicana             22.6             23.20
# 418  2023    4.0  enso_prec  cengicana             22.6             23.10
# 419  2023    4.0     neutro  cengicana             21.8             23.30
# 420  2023    4.0    atl_dom  cengicana             21.6             23.05
#
#      sem_iell_real  error_abs_prom  error_abs_pond  sem_iell _merge
# 91            24.0             0.0             0.0      24.0   both
# 92            24.0             0.0             0.0      24.0   both
# 93            24.0             0.0             0.0      24.0   both
# 94            24.0             0.0             0.0      24.0   both
# 95            24.0             0.0             0.0      24.0   both
# ..             ...             ...             ...       ...    ...
# 416           22.0             1.0             2.0      22.0   both
# 417           22.0             1.0             1.0      22.0   both
# 418           22.0             1.0             1.0      22.0   both
# 419           22.0             0.0             1.0      22.0   both
# 420           22.0             0.0             1.0      22.0   both
#
# [315 rows x 11 columns]

# %% [markdown]
# # cluster

# %%
cluster = pd.read_excel('data/analogos_years_icc_stations.xlsx')
cluster
# Out:
#    2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  ...  2016  \
# 0  1997  2002  2002  2001  2005  2003  2006  2001  2007  1999  ...  2014
# 1  2001  1999  1997  2004  2001  1997  1999  2000  2003  2003  ...  2010
# 2  2000  1997  2003  2003  2004  2002  2001  1997  2005  2008  ...  2003
# 3  1998  1998  2001  2002  2002  2004  2005  2002  1998  2004  ...  2007
# 4  1999  2001  1998  1997  1999  1998  2004  2004  1997  2006  ...  1997
#
#    2017  2018  2019  2020  2021  2022  2023  2024  2025
# 0  2016  2013  2002  1997  2008  2003  2018  2005  2014
# 1  2004  2003  2015  2019  2018  2018  2014  2020  2017
# 2  2013  2014  1997  2003  2011  2012  2019  2019  1997
# 3  1997  2005  2004  2005  2020  2015  2003  2001  2021
# 4  2005  2001  2000  2015  2003  2008  2001  2003  2020
#
# [5 rows x 24 columns]

# %%
iell[iell.station=='cengicana']
# Out:
#        station  year  sem_iell
# 127  cengicana  2024        23
# 128  cengicana  2023        22
# 129  cengicana  2022        19
# 130  cengicana  2021        22
# 131  cengicana  2020        24
# 132  cengicana  2019        25
# 133  cengicana  2018        18
# 134  cengicana  2017        23
# 135  cengicana  2016        23
# 136  cengicana  2015        18
# 137  cengicana  2014        22
# 138  cengicana  2013        23
# 139  cengicana  2012        16
# 140  cengicana  2011        19
# 141  cengicana  2010        19
# 142  cengicana  2009        23
# 143  cengicana  2008        20
# 144  cengicana  2007        24
# 145  cengicana  2006        19
# 146  cengicana  2005        22
# 147  cengicana  2004        24
# 148  cengicana  2003        24
# 149  cengicana  2002        23
# 150  cengicana  2001        25
# 151  cengicana  2000        26
# 152  cengicana  1999        23
# 153  cengicana  1998        31
# 154  cengicana  1997        28

# %%
result=[]
anos=[]
estaciones = []
for station in iell.station.unique():
    #print(station)
    for year in cluster.columns.to_list():
        mean = 0
        for i in range(5):
            star = iell[(iell.station==station) & (iell.year==int(cluster[year][i]))]
            if not star.empty:
                mean=mean + star.sem_iell.values[0]
        result.append(float(mean/5))
        anos.append(year)
        estaciones.append(station)
    
cluster_m = pd.DataFrame({
    'station': estaciones,
    'year': anos,
    'cluster': result
})
cluster_m
# Out:
#       station  year  cluster
# 0    lafragua  2002     29.8
# 1    lafragua  2003     30.6
# 2    lafragua  2004     31.0
# 3    lafragua  2005     33.0
# 4    lafragua  2006     33.4
# ..        ...   ...      ...
# 91  cengicana  2021     21.0
# 92  cengicana  2022     19.2
# 93  cengicana  2023     22.8
# 94  cengicana  2024     24.0
# 95  cengicana  2025     23.8
#
# [96 rows x 3 columns]

# %%
new_m = all_info[all_info['_merge']=='both'][['year','month','escenario','station','semana_promedio','semana_ponderada','sem_iell_real']].reset_index(drop=True)
new_m.rename(columns={'semana_promedio':'prom', 'semana_ponderada':'pd'}, inplace=True)

# %%
new_m
# Out:
#      year  month  escenario    station  prom     pd  sem_iell_real
# 0    2007    4.0   prec_dom  cengicana  23.6  23.50           24.0
# 1    2007    4.0   enso_dom  cengicana  23.6  23.50           24.0
# 2    2007    4.0  enso_prec  cengicana  23.6  23.50           24.0
# 3    2007    4.0     neutro  cengicana  23.6  23.80           24.0
# 4    2007    4.0    atl_dom  cengicana  23.6  23.80           24.0
# ..    ...    ...        ...        ...   ...    ...            ...
# 310  2023    4.0   prec_dom  cengicana  21.4  20.10           22.0
# 311  2023    4.0   enso_dom  cengicana  22.6  23.20           22.0
# 312  2023    4.0  enso_prec  cengicana  22.6  23.10           22.0
# 313  2023    4.0     neutro  cengicana  21.8  23.30           22.0
# 314  2023    4.0    atl_dom  cengicana  21.6  23.05           22.0
#
# [315 rows x 7 columns]

# %%
df_pivot = new_m.pivot_table(
    index=['year','station'],
    columns='escenario',
    values=['prom', 'pd'] # Especificamos ambas columnas que queremos pivotar
)
df_pivot.columns = [f"{col_name[1]}_{col_name[0]}" for col_name in df_pivot.columns]
df_pivot = df_pivot.reset_index()
complete_info = df_pivot.merge(new_m[['year', 'station', 'sem_iell_real']].drop_duplicates().reset_index(drop=True), how='inner', on=['year','station']).merge(cluster_m, how='inner', on=['year','station'])
complete_info
# Out:
#     year        station  atl_dom_pd  enso_dom_pd  enso_prec_pd  neutro_pd  \
# 0   2007      cengicana      23.800       23.500        23.500     23.800
# 1   2007    laborovalle      27.825       27.625        27.575     27.575
# 2   2007       lafragua      35.450       36.150        35.550     35.550
# 3   2007  puertosanjose      28.200       28.200        28.200     28.200
# 4   2008      cengicana      23.725       23.500        23.500     23.500
# 5   2008    laborovalle      29.825       28.325        28.550     28.550
# 6   2008       lafragua      32.000       31.050        31.050     31.050
# 7   2008  puertosanjose      26.000       25.775        25.775     26.000
# 8   2009      cengicana      21.425       21.725        21.725     21.725
# 9   2009    laborovalle      27.725       27.575        27.575     27.575
# 10  2009       lafragua      29.500       28.350        28.250     28.250
# 11  2009  puertosanjose      28.050       27.750        27.750     28.050
# 12  2010      cengicana      22.575       22.925        22.925     22.625
# 13  2010    laborovalle      28.875       28.200        28.200     28.950
# 14  2010       lafragua      34.250       34.825        34.225     34.825
# 15  2010  puertosanjose      29.025       29.125        29.125     29.125
# 16  2011      cengicana      21.725       22.700        21.950     21.950
# 17  2011    laborovalle      27.175       27.525        27.525     27.275
# 18  2011       lafragua      34.500       29.125        30.425     30.600
# 19  2011  puertosanjose      26.700       25.625        26.375     26.600
# 20  2012      cengicana      24.800       21.425        21.425     21.425
# 21  2012    laborovalle      27.875       27.025        27.125     26.900
# 22  2012       lafragua      28.675       29.775        29.775     29.250
# 23  2012  puertosanjose      27.675       27.600        27.600     27.600
# 24  2013      cengicana      23.100       23.675        23.675     23.075
# 25  2013    laborovalle      27.200       27.050        26.900     27.050
# 26  2013       lafragua      30.650       30.600        30.600     30.600
# 27  2013  puertosanjose      28.200       28.875        28.950     28.950
# 28  2014      cengicana      23.725       23.650        23.675     23.350
# 29  2014    laborovalle      27.250       28.100        27.550     27.525
# 30  2014       lafragua      30.550       30.450        30.525     29.925
# 31  2014  puertosanjose      29.425       29.700        29.550     29.550
# 32  2015      cengicana      22.300       22.925        22.900     22.900
# 33  2015    laborovalle      27.200       27.850        28.150     27.850
# 34  2015       lafragua      35.400       36.550        36.500     36.200
# 35  2015  puertosanjose      27.950       28.275        28.050     28.350
# 36  2016      cengicana      21.425       19.850        19.550     20.775
# 37  2016    laborovalle      27.150       29.675        28.725     28.800
# 38  2016       lafragua      29.300       33.100        33.200     32.175
# 39  2016  puertosanjose      28.375       27.525        29.925     31.350
# 40  2017      cengicana      23.050       23.200        23.200     23.125
# 41  2017    laborovalle      27.250       27.325        27.325     27.325
# 42  2017       lafragua      30.425       30.625        30.475     30.625
# 43  2017  puertosanjose      28.850       29.475        29.550     28.950
# 44  2018      cengicana      19.325       18.650        18.650     19.400
# 45  2018    laborovalle      26.875       26.800        26.800     26.725
# 46  2018       lafragua      28.225       29.375        29.425     28.675
# 47  2018  puertosanjose      29.000       28.450        28.975     28.975
# 48  2019      cengicana      23.150       22.400        23.050     23.350
# 49  2019    laborovalle      31.100       29.600        29.900     30.475
# 50  2019       lafragua      33.900       34.350        33.975     33.975
# 51  2019  puertosanjose      28.800       30.600        30.825     29.325
# 52  2020      cengicana      22.225       22.975        22.900     22.400
# 53  2021      cengicana      21.075       18.000        18.000     19.925
# 54  2022      cengicana      21.525       18.650        18.650     19.800
# 55  2023      cengicana      23.050       23.200        23.100     23.300
#
#     prec_dom_pd  atl_dom_prom  enso_dom_prom  enso_prec_prom  neutro_prom  \
# 0        23.500          23.6           23.6            23.6         23.6
# 1        27.575          28.0           28.0            28.0         28.0
# 2        35.550          32.2           33.8            32.2         32.2
# 3        29.025          28.8           28.8            28.8         28.8
# 4        22.200          23.4           23.2            23.2         23.2
# 5        28.550          28.8           28.2            28.8         28.8
# 6        35.600          33.0           31.0            31.0         31.0
# 7        26.775          28.0           27.4            27.4         28.0
# 8        21.200          23.2           23.2            23.2         23.2
# 9        28.325          28.6           28.2            28.2         28.2
# 10       31.000          29.8           29.4            29.4         29.4
# 11       28.050          28.2           27.4            27.4         28.2
# 12       21.675          22.8           23.4            23.4         22.6
# 13       29.175          28.4           28.6            28.6         28.6
# 14       32.225          34.0           35.2            33.6         35.2
# 15       29.975          29.0           29.0            29.0         29.0
# 16       22.125          23.0           23.4            23.4         23.4
# 17       26.800          28.6           28.6            28.6         28.6
# 18       33.925          33.2           30.4            31.6         31.6
# 19       26.700          27.4           26.8            26.8         27.4
# 20       22.625          23.4           23.2            23.2         23.2
# 21       29.050          28.6           28.2            28.2         27.6
# 22       29.750          29.6           31.0            31.0         29.6
# 23       27.850          27.6           27.2            27.2         27.2
# 24       24.550          22.8           22.8            22.8         22.8
# 25       27.350          27.6           27.6            27.2         27.6
# 26       32.750          30.8           30.8            30.8         30.8
# 27       27.750          28.8           28.6            28.8         28.8
# 28       22.975          23.8           23.8            23.8         23.8
# 29       27.750          27.6           27.6            27.6         27.4
# 30       31.600          31.8           30.6            30.8         29.2
# 31       28.125          28.2           29.2            28.8         28.8
# 32       21.925          21.8           23.4            23.4         23.4
# 33       27.675          27.0           28.6            28.6         28.6
# 34       34.750          33.0           34.6            34.6         34.6
# 35       28.125          28.2           29.0            28.2         29.0
# 36       22.300          22.2           21.4            21.4         22.2
# 37       29.075          27.8           28.2            28.0         28.0
# 38       29.925          31.4           33.8            33.6         31.4
# 39       28.875          30.0           28.8            29.6         30.2
# 40       23.525          23.6           23.4            23.4         23.4
# 41       27.450          26.6           26.8            26.8         26.8
# 42       30.100          30.2           30.6            30.6         30.6
# 43       29.550          28.6           28.6            28.8         28.6
# 44       19.000          21.0           21.2            21.2         21.2
# 45       27.550          27.8           27.6            27.4         27.4
# 46       29.425          29.2           29.8            29.8         29.0
# 47       28.250          28.0           28.6            28.6         28.6
# 48       23.800          22.2           22.4            22.4         22.4
# 49       29.500          30.2           29.2            30.0         30.0
# 50       33.225          33.2           34.8            33.4         33.4
# 51       29.250          30.2           29.6            30.2         30.2
# 52       23.200          22.4           22.6            22.4         22.4
# 53       18.425          20.2           19.8            19.8         19.8
# 54       18.575          21.4           20.4            20.4         20.6
# 55       20.100          21.6           22.6            22.6         21.8
#
#     prec_dom_prom  sem_iell_real  cluster
# 0            23.6           24.0     26.0
# 1            27.4           30.0     30.4
# 2            32.2           33.0     33.0
# 3            28.8           31.0     30.6
# 4            22.6           20.0     22.6
# 5            28.8           31.0     28.2
# 6            32.2           31.0     32.6
# 7            28.2           30.0     27.0
# 8            22.6           23.0     25.2
# 9            28.2           26.0     28.2
# 10           30.6           34.0     31.4
# 11           28.2           27.0     29.0
# 12           22.4           19.0     25.8
# 13           29.2           28.0     30.6
# 14           33.6           28.0     32.6
# 15           29.0           24.0     30.8
# 16           23.6           19.0     22.0
# 17           27.6           30.0     29.6
# 18           31.6           34.0     33.0
# 19           27.4           28.0     27.6
# 20           22.8           16.0     22.4
# 21           28.2           28.0     29.2
# 22           32.0           30.0     33.4
# 23           27.8           29.0     27.8
# 24           23.4           23.0     23.2
# 25           27.6           29.0     27.6
# 26           32.4           29.0     31.2
# 27           28.8           30.0     28.0
# 28           22.4           22.0     24.4
# 29           27.6           25.0     29.6
# 30           31.8           30.0     31.8
# 31           28.6           26.0     30.6
# 32           20.8           18.0     21.6
# 33           27.4           31.0     28.6
# 34           33.0           32.0     31.8
# 35           28.4           33.0     28.8
# 36           22.2           23.0     23.4
# 37           27.8           32.0     28.8
# 38           31.4           34.0     31.4
# 39           28.4           28.0     28.6
# 40           24.2           23.0     24.0
# 41           28.4           32.0     29.4
# 42           30.6           27.0     33.6
# 43           28.8           25.0     28.8
# 44           20.2           18.0     23.2
# 45           28.2           27.0     27.6
# 46           29.2           34.0     31.6
# 47           28.2           28.0     28.6
# 48           24.0           25.0     23.8
# 49           28.8           27.0     29.0
# 50           32.2           26.0     32.0
# 51           29.4           25.0     29.6
# 52           23.4           24.0     23.4
# 53           20.0           22.0     21.0
# 54           20.2           19.0     19.2
# 55           21.4           22.0     22.8

# %%
fases = pd.DataFrame({
    'year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
       2018, 2019, 2020, 2021, 2022, 2023],
    'fase': ['neutro', 'nina', 'nina', 'nino', 'nina', 'nina', 'neutro', 'neutro', 'nino', 'nino','nina', 'nina', 'nino', 'neutro', 'nina', 'nina', 'nina' ]
})
fases
# Out:
#     year    fase
# 0   2007  neutro
# 1   2008    nina
# 2   2009    nina
# 3   2010    nino
# 4   2011    nina
# 5   2012    nina
# 6   2013  neutro
# 7   2014  neutro
# 8   2015    nino
# 9   2016    nino
# 10  2017    nina
# 11  2018    nina
# 12  2019    nino
# 13  2020  neutro
# 14  2021    nina
# 15  2022    nina
# 16  2023    nina

# %%
complete_info.merge(fases, how='inner', on='year').to_csv('data/predicciones_all.csv')
